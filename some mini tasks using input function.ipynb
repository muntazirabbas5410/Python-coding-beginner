# %%
## Make a management system
print("="*60)
print("percent Calculator")
print("="*60)
English = float(input("enter the English marks"))
Maths = float(input("enter the Maths marks"))
Urdu = float(input("enter the Urdu marks"))
Islamiat = float(input("enter the Islamiyat marks"))
Science = float(input("enter the Science marks"))
total_marks = int(input("enter the total marks"))


obtained_marks = English + Maths + Urdu + Islamiat + Science

print(f"sum of all subjects",English + Maths + Urdu + Islamiat + Science )
Percentage = obtained_marks/total_marks*100
Average = obtained_marks/5

print(f"percentage of subject marks: {Percentage}")
print(f"Average of subject : {Average}")
# Out:
# ...
# percent Calculator
# ...
# enter the English marks88.5
# enter the Maths marks78.4
# enter the Urdu marks56.6
# enter the Islamiyat marks78.8
# enter the Science marks67.7
# enter the total marks500
# sum of all subjects 370.0
# percentage of subject marks: 74.0
# Average of subject : 74.0

# %% [markdown]
# ### **Tuple**
# immutable(unchangable)

# %%
fruits = ("apple","banana","cherry")
print(fruits)
print(type(fruits))
# Out:
# ('apple', 'banana', 'cherry')
# <class 'tuple'>

# %% [markdown]
# ### **Accessing Elements**
# You can access tuple elements using indexing and slicing:

# %%
fruits = ('apple', 'banana', 'cherry')
print(fruits[0])  # First element
print(fruits[-1])  # Last element
# Out:
# apple
# cherry

# %%
fruits = ('apple', 'banana', 'cherry', 'orange')
print(fruits[1:3])  # Slicing
# Out:
# ('banana', 'cherry')

# %% [markdown]
# ### **Length of a Tuple**
# Use len() to find the number of elements in a tuple:

# %%
fruits = ('apple', 'banana', 'cherry')
print(len(fruits))
# Out:
# 3

# %% [markdown]
# ### **Tuple Concatenation and Repetition**
# Use + to combine two tuples.
# Use * to repeat a tuple.

# %%
A = (1, 2, 3)
B = (4, 5)
print(A + B)  # Concatenation
print(A * 2)  # Repetition
# Out:
# (1, 2, 3, 4, 5)
# (1, 2, 3, 1, 2, 3)

# %% [markdown]
# ### **Tuple Unpacking**
# You can unpack tuple elements into variables:

# %%
coordinates = (10, 20)
x, y = coordinates
print(x)
print(y)
# Out:
# 10
# 20

# %% [markdown]
# ### **Nesting Tuples**
# Tuples can contain other tuples:

# %%
nested = ((1, 2), (3, 4), (5, 6))
print(nested[0])
print(nested[0][1])
# Out:
# (1, 2)
# 2

# %% [markdown]
#  ### **Tuple Methods**
# count() – Returns the number of occurrences of a value.
# index() – Returns the index of the first occurrence of a value.

# %%
fruits = ('apple', 'banana', 'cherry', 'apple')
print(fruits.count('apple'))
print(fruits.index('banana'))
# Out:
# 2
# 1

# %% [markdown]
# ### **Checking Membership**
# Use in and not in to check if an element exists in a tuple:

# %%
fruits = ('apple', 'banana', 'cherry')
print('apple' in fruits)
print('mango' not in fruits)
# Out:
# True
# True

# %% [markdown]
# ### **Sorting a Tuple**
# You can't sort a tuple directly, but you can create a sorted list from it:

# %%
numbers = (3, 1, 4, 2)
sorted_numbers = sorted(numbers)
print(sorted_numbers)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
#  ### **Convert Tuple to List and Vice Versa**
# You can convert a tuple to a list and back:

# %%
fruits = ('apple', 'banana', 'cherry')
fruits_list = list(fruits)
print(fruits_list)
fruits_tuple = tuple(fruits_list)
print(fruits_tuple)
# Out:
# ['apple', 'banana', 'cherry']
# ('apple', 'banana', 'cherry')
