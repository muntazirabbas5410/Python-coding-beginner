# %%
print("Muntazir Abbas")
print(3)
print("Muntazir", "Abbas", "khurasani")
print(1,2,3,4,5)
# Out:
# Muntazir Abbas
# 3
# Muntazir Abbas khurasani
# 1 2 3 4 5

# %%
print("MY INTRODUCTION")
print("My name is muntazir abbas khuirasani, iam from Danyore. Iam doing my bechelors in Data sciences from KIU gilgit.")
# Out:
# MY INTRODUCTION
# My name is muntazir abbas khuirasani, iam from Danyore. Iam doing my bechelors in Data sciences from KIU gilgit.

# %% [markdown]
# #There are two types of prints
# ###*simple print
# ###*f-print

# %%
name = "Ali"
age = 21
height = 5.22
print(name, age, height)
print(type(name))
print(type(age))
print(type(height))
# Out:
# Ali 21 5.22
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
print(f"Name {"Ali"}, age {21}, height {5.22}")
# Out:
# Name Ali, age 21, height 5.22

# %%
print(f"Hello everyone! my age is :{21}")
# Out:
# Hello everyone! my age is :21
